# %%
# 02_qa_dataset_eda.ipynb -- EDA cho Final QA Dataset
# Chay sau khi data/processed/datasets/qa_dataset_final.jsonl duoc sinh ra
import sys
from pathlib import Path
ROOT = Path.cwd().resolve()
sys.path.append(str(ROOT))
from src.config import QA_FINAL, FIGURES_DIR
import pandas as pd
print('Waiting for QA dataset at:', QA_FINAL)
